# %%
import numpy as np
# array1 = np.array([1, 2, 3])
# print('array 1 type: ', type(array1))
# print('array1 array 형태: ', array1.shape)

# array2 = np.array([[1, 2, 3], [2, 3, 4]])
# print('array 2 type: ', type(array2))
# print('array2 array 형태: ', array2.shape)

# array3 = np.array([[1, 2, 3]])
# print('array 3 type: ', type(array3))
# print('array3 array 형태: ', array3.shape)

# print('array: {0}차원, array2: {1}차원, array3: {2}차원'.format(array1.ndim, array2.ndim, array3.ndim))

# np.array(리스트) -> 리스트를 ndarray로 변환
# type(객체) -> 어떤 타입인지 알려줌
# ndarray.shape -> ndarray의 차원과 크기를 순서쌍으로 알려줌 (행, 열)
# ndarray.ndim -> ndarray 차원을 알려줌

# list1 = [1, 2, 3]
# print(type(list1))
# array1 = np.array(list1)
# print(type(array1))
# print(array1, array1.dtype)

# list2 = [1, 2, 'test']
# array2 = np.array(list2)
# print(array2, array2.dtype)

# list3 = [1, 2, 3.0]
# array3 = np.array(list3)
# print(array3, array3.dtype)

# ndarray.dtype -> 배열 원소들의 데이터 타입을 알려준다 (같은 데이터 타입으로만 구성되어야 한다)

# array_int = np.array([1, 2, 3])
# array_float = array_int.astype('float64')
# print(array_float, array_float.dtype)

# array_int1 = array_float.astype('int32')
# print(array_int1, array_int1.dtype)

# array_float1 = np.array([1.1, 2.1, 3.1])
# array_int2 = array_float1.astype('int32')
# print(array_int2, array_int2.dtype)

# ndarray.astype('변환을 원하는 타입명') -> 배열 원소들의 데이터 타입을 변환해준다

# sequence_array = np.arange(10)
# print(sequence_array)
# print(sequence_array.dtype, sequence_array.shape)

# np.arange(원하는 배열 크기) -> 0부터 원하는 배열의 크기 -1까지의 정수로 이루어진 1차원 배열을 생성해준다

# zero_array = np.zeros((3, 2), dtype = 'int32')
# print(zero_array)
# print(zero_array.dtype, zero_array.shape)

# one_array = np.ones((3, 2))
# print(one_array)
# print(one_array.dtype, one_array.shape)


# np.zeros((행, 열), 데이터타입(생략가능)) -> 0으로 채워진 배열 생성
# np.ones((행, 열), 데이터타입(생략가능)) -> 1로 채워진 배열 생성
# 디폴트 데이터 타입은 float64형, 뒤에 s가 붙는 걸 조심

# array1 = np.arange(10)
# print('array1:\n', array1)

# array2 = array1.reshape(2, 5)
# print('array2: \n', array2)

# array3 = array2.reshape(5, 2)
# print('array3: \n', array3)

# ndarray.reshape(행, 열) -> 배열을 원하는 행열로 바꾸어준다. 단 배열의 원소의 개수와 맞지 않게는 변형할 수 없다.

# array1 = np.arange(10)
# print(array1)

# array2 = array1.reshape(-1, 5)
# print(array2)

# array3 = array1.reshape(5, -1)
# print(array3)

# array4 = array1.reshape(-1, 1)
# print(array4)

# ndarray.reshape()의 인자에 -1을 넣으면 배열의 원소에 맞게 알아서 reshape해준다.

# array1 = np.arange(8)
# array3d =array1.reshape((2, 2, 2))
# print('array3d:\n', array3d.tolist())

# # 3차원 ndarray를 2차원 ndarray로 변환
# array5 = array3d.reshape(-1, 1)
# print('array5: \n', array5.tolist())
# print('array5 shape: ', array5.shape)

# # 1차원 ndarray를 2차원 ndarray로 변환
# array6 = array1.reshape(-1, 1)
# print('array6: \n', array6.tolist())
# print('array6 shape:', array6.shape)

# ndarray.reshape()를 통해 배열의 차원을 바꿀 수도 있다
# ndarray.tolist()를 이용해 ndarray형을 list형으로 바꿀 수 있다

#1부터 9까지의 1차원 ndarray 생성
# array1 = np.arange(start = 1, stop = 10)
# print('array1 :', array1)

# #index는 0부터 시작하므로 array1[2]는 3번째 index 위치의 데이터값을 의미
# value = array1[2]
# print('value:', value)
# print(type(value))
# print('맨 뒤의 값:', array1[-1], '맨 뒤에서 두번째 값', array1[-2])

# array1[0] = 9
# array1[8] = 0
# print('array1:', array1)

# np.arange(start, stop) -> start 수부터 stop -1 수까지 1씩 증가한 원소를 가지는 배열 생성

# array1d = np.arange(start = 1, stop = 10)
# array2d = array1d.reshape(3, 3);
# print(array2d)

# print('(row = 0, col = 0) index 가리키는 값:', array2d[0, 0])
# print('(row = 0, col = 1) index 가리키는 값:', array2d[0, 1])
# print('(row = 1, col = 0) index 가리키는 값:', array2d[1, 0])
# print('(row = 2, col = 2) index 가리키는 값:', array2d[2, 2])

# nparray의 2차원 배열일 경우 2차원배열명[행, 열]로 데이터에 접근할 수 있다

# array1 = np.arange(start = 1, stop = 10)
# array3 = array1[0:3]
# print(array1)
# print(array3)
# print(type(array3))

# arrary1 = np.arange(start = 1, stop = 10)
# array4 = array1[:3]
# print(array4)

# array5 = array1[3:]
# print(array5)

# array6 = array1[:]
# print(array6)

# nparray[시작인덱스:마지막인덱스] -> 배열을 원하는 구간만큼 잘라준다. 단 마지막 인덱스 -1까지

# array1d = np.arange(start = 1, stop = 10)
# array2d = array1d.reshape(3, 3)
# print('array2d:', array2d)

# print('array2d[0:2, 0:2] \n', array2d[0:2, 0:2])
# print('array2d[1:3, 0:3] \n', array2d[1:3, 0:3])
# print('array2d[1:3, :] \n', array2d[1:3, :])
# print('array2d[:, :] \n', array2d[:, :])
# print('array2d[:2, 1:] \n', array2d[:2, 1:])
# print('array2d[:2, 0] \n', array2d[:2, 0])

# print(array2d[0])
# print(array2d[1])
# print('array2d[0] shape:', array2d[0].shape, 'array2d[1] shape:', array2d[1].shape)

# ndarray[:, :] 앞의 : 은 행, 뒤의 : 열

# array1d = np.arange(start = 1, stop = 10)
# array2d = array1d.reshape(3, 3)

# array3 = array2d[[0, 1], 2]
# print('array2d[[0, 1], 2] =>', array3.tolist())
            
# array4 = array2d[[0, 1], 0:2]
# print('array2d[[0, 1], 0:2] =>', array4.tolist())

# fency indexing

# array1d = np.arange(start = 1, stop = 10)
# # [] 안에 array1d > 5 Boolean indexing 적용
# array3 = array1d[array1d > 5]
# print('array1d > 5 불린 인덱싱 결과 값: ', array3)
# array1d > 5
# boolean_indexs = np.array([False, False, False, False, False, True, True, True, True])
# array3 = array1d[boolean_indexs]
# print(array3)

# boolean indexing - ndarray[조건식] -> true에 해당하는 index 값만 저장해서 반환

# org_array = np.array([3, 1, 9, 5])
# print('원본 행렬:', org_array)
# # np.sort()로 정렬
# sort_array1 = np.sort(org_array)
# print('np.sort() 호출 후 반환된 정렬 행렬:', sort_array1)
# print('np.sort() 호출 후 원본 행렬:', org_array)
# # ndarray.sort()로 정렬
# sort_array2 = org_array.sort()
# print('org_array.sort() 호출 후 반환된 행렬:', sort_array2)
# print('org_array.sort() 호출 후 원본 행렬:', org_array)
# # 내림차순 정렬
# sort_array1_desc = np.sort(org_array)[::-1]
# print('내림차순 정렬:', sort_array1_desc)
# # 2차원 ndarray 정렬
# array2d = np.array([[8, 12], [7, 1]])
# sort_array2d_axis0 = np.sort(array2d, axis = 0)
# print('로우 방향으로 정렬: \n', sort_array2d_axis0)

# sort_array2d_axis1 = np.sort(array2d, axis = 1)
# print('칼럼 방향으로 정렬: \n', sort_array2d_axis1)

# # np.sort(ndaary) -> 원본 배열은 그대로 두고 정렬된 배열을 반환
# # narray.sort() -> 원본 배열을 정렬한 배열로 변환하고 아무것도 반환하지 않음
# # np.sort(ndaary, axis = ?) 행 또는 열 방향으로 정렬

# org_array = np.array([3, 1, 9, 5])
# sort_indicies = np.argsort(org_array)
# print(type(sort_indicies))
# print('행렬 정렬 시 원본 행렬의 인덱스:', sort_indicies)

# sort_indices_desc = np.argsort(org_array)[::-1]
# print('행렬 내림차순 정렬 시 원본 행렬의 인덱스:', sort_indices_desc)

# np.argsort(ndarray) -> 배열을 오름차순으로 정렬하고 정렬전 인덱스를 ndarray의 타입으로 변환하여 반환함

# name_array = np.array(['존', '마이크', '사라', '케이트', '사무엘'])
# score_array = np.array([78, 95, 84, 98, 88])

# sort_indices_asc = np.argsort(score_array)
# print('성적 오름차순 정렬 시 score_array의 인덱스:', sort_indices_asc)
# print('성적 오름차순 정렬 시 name_array의 인덱스:', name_array[sort_indices_asc])

# np.argsort(ndarray)를 통해 반환된 ndarray를 다른 ndarray의 인덱스로 활용할 때가 많다

# A = np.array([[1, 2, 3], [4, 5, 6]])
# B = np.array([[7, 8], [9, 10], [11, 12]])
# dot_product = np.dot(A, B)
# print('행렬 내적 결과:', dot_product)

# np.dot(ndarray, ndarray) -> 행렬의 곱을 구하고 그 값을 반환함

A = np.array([[1, 2], [3, 4]])
transpose_mat = np.transpose(A)
print('A의 전치 행렬:\n', transpose_mat)

# np.transpose(ndarray) -> 인자의 transpose mtx를 반환함
# Out:
# A의 전치 행렬:
#  [[1 3]
#  [2 4]]
